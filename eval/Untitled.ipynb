# %%
import numpy as np
from matplotlib import pyplot as plt
import json

# %%
files = ['../results/sacred/qmix/mpe:TerrainDependantNavigation-v0/1',
        '../results/sacred/qmix/mpe:TerrainDependantNavigation-v0/2',
        '../results/sacred/qmix/mpe:HeterogeneousMaterialTransport-v0/2',
        '../results/sacred/qmix/mpe:HeterogeneousMaterialTransport-v0/1',
        '../results/sacred/qmix/mpe:HeterogeneousSensorNetwork-v0/1',
        '../results/sacred/qmix/mpe:HeterogeneousSensorNetwork-v0/2']

for i,file in enumerate(files):
    f = open(file + '/eval.json',)
    data = json.load(f)
    print(data['het_config']['use_agent_id'])
    plt.figure(i // 2)
    plt.violinplot(data['rew'], positions=[data['het_config']['use_agent_id'] * 1])
# Out:
# False
# True
# False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/_z/8dcphyld64jfmcfs6cjc_3xh0000gn/T/ipykernel_7169/370532822.py in <module>
#       7
#       8 for i,file in enumerate(files):
# ----> 9     f = open(file + '/eval.json',)
#      10     data = json.load(f)
#      11     print(data['het_config']['use_agent_id'])
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/sacred/qmix/mpe:HeterogeneousMaterialTransport-v0/1/eval.json'

# %%
import moviepy.editor as mp
import os
files = os.listdir('gifs')
for file in files:
    clip = mp.VideoFileClip("gifs/" + file)
    clip.write_videofile('mp4/' + file[:-4] + '.mp4')
